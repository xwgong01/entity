# %%
import nt2

data = nt2.Data(path="mi25-MA40")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import nt2
#       3 data = nt2.Data(path="mi25-MA40")
#
# ModuleNotFoundError: No module named 'nt2'
